# %% [markdown]
# # Installation

# %%
# !pip install kornia
# Out:
# Collecting kornia
#   Downloading kornia-0.6.12-py2.py3-none-any.whl (653 kB)
#      ------------------------------------ 653.4/653.4 kB 228.6 kB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\hp\anaconda3\lib\site-packages (from kornia) (21.3)
# Requirement already satisfied: torch>=1.9.1 in c:\users\hp\anaconda3\lib\site-packages (from kornia) (2.0.0)
# Requirement already satisfied: filelock in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.9.1->kornia) (3.6.0)
# Requirement already satisfied: typing-extensions in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.9.1->kornia) (4.3.0)
# Requirement already satisfied: sympy in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.9.1->kornia) (1.10.1)
# Requirement already satisfied: networkx in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.9.1->kornia) (2.8.4)
# Requirement already satisfied: jinja2 in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.9.1->kornia) (2.11.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\hp\anaconda3\lib\site-packages (from packaging->kornia) (3.0.9)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\hp\anaconda3\lib\site-packages (from jinja2->torch>=1.9.1->kornia) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\hp\anaconda3\lib\site-packages (from sympy->torch>=1.9.1->kornia) (1.2.1)
# Installing collected packages: kornia
# Successfully installed kornia-0.6.12

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\hp\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %% [markdown]
# # Import libraries

# %%
import torch
import torchvision
import kornia
import cv2
import pandas
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Read and display an Image

# %%
image=cv2.imread("Test1.png")
img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %% [markdown]
# # Convert an RGB image to tensor image

# %%
tensor_image=kornia.utils.image_to_tensor(img, keepdim=False).float()
print(tensor_image.shape)
print(tensor_image)
# Out:
# torch.Size([1, 3, 128, 128])
# tensor([[[[ 56.,  58.,  55.,  ...,  26.,  26.,  26.],
#           [ 60.,  56.,  51.,  ...,  25.,  25.,  24.],
#           [ 66.,  56.,  53.,  ...,  24.,  23.,  21.],
#           ...,
#           [ 26.,  26.,  27.,  ..., 118., 113., 122.],
#           [ 27.,  27.,  27.,  ..., 113., 120., 121.],
#           [ 28.,  28.,  26.,  ..., 109., 119., 117.]],
#
#          [[ 87.,  86.,  85.,  ...,  34.,  34.,  38.],
#           [ 94.,  91.,  87.,  ...,  35.,  34.,  36.],
#           [103.,  92.,  88.,  ...,  33.,  33.,  33.],
#           ...,
#           [ 47.,  48.,  49.,  ..., 154., 152., 157.],
#           [ 48.,  48.,  49.,  ..., 150., 156., 159.],
#           [ 50.,  49.,  49.,  ..., 145., 154., 155.]],
#
#          [[ 36.,  35.,  37.,  ...,  25.,  25.,  26.],
#           [ 38.,  38.,  38.,  ...,  21.,  21.,  22.],
#           [ 43.,  39.,  37.,  ...,  18.,  17.,  17.],
#           ...,
#           [ 19.,  20.,  21.,  ...,  66.,  61.,  70.],
#           [ 20.,  20.,  22.,  ...,  64.,  68.,  68.],
#           [ 19.,  20.,  22.,  ...,  63.,  71.,  68.]]]])

# %% [markdown]
# # Convert an tensor image to RGB image

# %%
img= kornia.tensor_to_image(tensor_image.byte())
plt.imshow(img)

# %% [markdown]
# # RGB to Gray Scale Conversion

# %%
#Read an RGB image
image=cv2.imread("Test1.png")
img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

#Convert an image to tensor
tensor_image=kornia.utils.image_to_tensor(img, keepdim=False).float()

#Convert an RGB to Gray Scale image
gray=kornia.color.rgb_to_grayscale(tensor_image)

#Convert a tensor to image
img1= kornia.tensor_to_image(gray)

#Save the gray scale image
cv2.imwrite('gray.png',img1)

#Subplotting the images
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax1.imshow(img)
ax2 = fig.add_subplot(1,2,2)
ax2.imshow(img1,cmap="gray")

# %% [markdown]
# # Gray Scale to RGB Conversion

# %%
#Read a Gray Scale image
image=cv2.imread('gray.png')
img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

#Convert an image to tensor
tensor_image=kornia.utils.image_to_tensor(img,keepdim=False)

#Convert a Gray Scale to RGB image
img1=kornia.color.grayscale_to_rgb(tensor_image)

#Convert a tensor to image
img1= kornia.tensor_to_image(img1)

#Subplotting the images
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax1.imshow(img,cmap='gray')
ax2 = fig.add_subplot(1,2,2)
ax2.imshow(img1)

# %% [markdown]
# # BGR to GrayScale conversion

# %%
#Read a BGR image
image=cv2.imread("bgr.png")
#img = cv2.cvtColor(image, cv2.COLOR_BGR2PNG)

#Convert an image to tensor
tensor_image=kornia.utils.image_to_tensor(image, keepdim=False).float()

#Convert a BGR to Gray Scale image
gray=kornia.color.bgr_to_grayscale(tensor_image)

#Convert a tensor to image
img1= kornia.tensor_to_image(gray)

#Subplotting the images
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax1.imshow(image)
ax2 = fig.add_subplot(1,2,2)
ax2.imshow(img1,cmap="gray")

# %% [markdown]
# # RGB to BGR Conversion

# %%
#Read an RGB image
image=cv2.imread("Test1.png")
img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

#Convert an image to tensor
tensor_image=kornia.utils.image_to_tensor(img, keepdim=False).float()

#Convert an RGB to BGR image
bgr=kornia.color.rgb_to_bgr(tensor_image)

#Convert a tensor to image
img1= kornia.tensor_to_image(bgr.byte())

#Save the gray scale image
cv2.imwrite('bgr.png',img1)

#Subplotting the images
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax1.imshow(img)
ax2 = fig.add_subplot(1,2,2)
ax2.imshow(img1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11552\1893478115.py in <module>
#       1 #Read an RGB image
# ----> 2 image=cv2.imread("Test1.png")
#       3 img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#       4
#       5 #Convert an image to tensor
#
# NameError: name 'cv2' is not defined

# %% [markdown]
# # BGR to RGB conversion

# %%
#Read a BGR image
image=cv2.imread("bgr.png")
#img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

#Convert an image to tensor
tensor_image=kornia.utils.image_to_tensor(image, keepdim=False).float()

#Convert an RGB to BGR image
rgb=kornia.color.bgr_to_rgb(tensor_image)

#Convert a tensor to image
img1= kornia.tensor_to_image(rgb.byte())

#Subplotting the images
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax1.imshow(image)
ax2 = fig.add_subplot(1,2,2)
ax2.imshow(img1)

# %% [markdown]
# # RGB to HLS Conversion

# %%
#Read an RGB image
image=cv2.imread("Test1.png")
img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

#Convert an image to tensor
tensor_image=kornia.utils.image_to_tensor(img, keepdim=False).float()

#Convert an RGB to HLS image
hls=kornia.color.rgb_to_hls(tensor_image)

#Convert a tensor to image
img1= kornia.tensor_to_image(hls)

#Save the gray scale image
cv2.imwrite('hls.png',img1)

#Subplotting the images
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax1.imshow(img)
ax2 = fig.add_subplot(1,2,2)
ax2.imshow(img1)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # RGB to HSV Conversion

# %%
#Read an RGB image
image=cv2.imread("Test1.png")
img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

#Convert an image to tensor
tensor_image=kornia.utils.image_to_tensor(img, keepdim=False).float()

#Convert an RGB to HSV image
h=kornia.color.rgb_to_hsv(tensor_image)

#Convert a tensor to image
img1= kornia.tensor_to_image(h)

#Save the gray scale image
cv2.imwrite('hsv.png',img1)

#Subplotting the images
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax1.imshow(img)
ax2 = fig.add_subplot(1,2,2)
ax2.imshow(img1)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # RGB to YCbCr conversion

# %%
#Read an RGB image
image=cv2.imread("Test1.png")
img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

#Convert an image to tensor
tensor_image=kornia.utils.image_to_tensor(img, keepdim=False).float()

#Convert an RGB to YCbCr image
y=kornia.color.rgb_to_ycbcr(tensor_image)

#Convert a tensor to image
img1= kornia.tensor_to_image(y)

#Save the YCbCr image
cv2.imwrite('YCbCr.png',img1)

#Subplotting the images
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax1.imshow(img)
ax2 = fig.add_subplot(1,2,2)
ax2.imshow(img1)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
